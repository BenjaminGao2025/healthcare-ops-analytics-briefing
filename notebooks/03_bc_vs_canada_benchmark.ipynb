# %% [markdown]
# # BC vs Canada Benchmark\n\nTODO:\n- Compare BC and Canada median wait values by procedure.\n- Compare BC and Canada p90 wait values by procedure.\n- Calculate benchmark compliance gaps where data is available.\n- Identify the largest procedure-level gaps for executive review.\n- Save final tables for Streamlit and the briefing deck.\n
