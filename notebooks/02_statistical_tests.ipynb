# %% [markdown]
# # Statistical Tests\n\nTODO:\n- Calculate descriptive statistics for selected wait-time indicators.\n- Compare recent-year values against earlier reporting periods.\n- Prepare correlation inputs for case volume and median wait.\n- Draft clear caveats for aggregate public-data interpretation.\n- Save summary tables for the analyst report.\n
